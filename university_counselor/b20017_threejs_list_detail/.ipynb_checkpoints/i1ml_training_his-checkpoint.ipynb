# %% [markdown]
# import argparse
# from time import time
# import os
# import numpy as np
# import random
# import json
# import pickle

# %% [markdown]
# print('一种新颖的基于类别感知分层记忆网络的推荐器来学习健康感知用户与食谱的交互，\
#       从而获得更好的食物推荐。此外，大量实验证明了健康意识食物推荐方案的有效性')

# %%
print('运行时候内存/cpu/gpu系统负载情况：')
# Out:
# 运行时候内存/cpu/gpu系统负载情况：

# %% [markdown]
# ![1.jpg](attachment:1.jpg)

# %%
print('训练某epoch中，batch循环的过程：')
# Out:
# 训练某epoch中，batch循环的过程：

# %% [markdown]
# ![title](resources/2.jpg)

# %%
print('最终训练结果的模型情况:')
# Out:
# 最终训练结果的模型情况:

# %% [markdown]
# ![title](resources/3.jpg)

# %%
print('总的处理流程为:')
# Out:
# 总的算法模型为:

# %% [markdown]
# ![theory.png](attachment:theory.png)

# %%
print("建议的推荐器，由四个部分组成：一般记忆、个人记忆、类别嵌入和配方嵌入。 给定用户 u 和菜谱 i，"
     +" 推荐器首先获得用户 u 的个人和一般记忆以及菜谱 i 的菜谱和类别嵌入。 之后，它分层计算匹配分数。")
# Out:
# 建议的推荐器，由四个部分组成：一般记忆、个人记忆、类别嵌入和配方嵌入。 给定用户 u 和菜谱 i， 推荐器首先获得用户 u 的个人和一般记忆以及菜谱 i 的菜谱和类别嵌入。 之后，它分层计算匹配分数。

# %% [markdown]
# ![title](resources/theory1.png)

# %%
print("主要算法函数：")
# Out:
# 主要算法函数：

# %% [markdown]
# ![title](resources/m1.jpg)

# %% [markdown]
# ![title](resources/m2.jpg)
